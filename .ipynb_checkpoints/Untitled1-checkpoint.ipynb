# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.rand?

# %%
a = [1,2,3
    ]

# %%
a.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7d211d06e928> in <module>()
# ----> 1 a.len()
#
# AttributeError: 'list' object has no attribute 'len'

# %%
a.lenth()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c0c86f07227f> in <module>()
# ----> 1 a.lenth()
#
# AttributeError: 'list' object has no attribute 'lenth'

# %%
a.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6278443a8889> in <module>()
# ----> 1 a.len
#
# AttributeError: 'list' object has no attribute 'len'

# %%
pd.DataFrame(-1+2*np.random.rand(40,20))
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.195348 -0.143826 -0.953449 -0.925942  0.658547 -0.797165 -0.985763
# 1  -0.782921  0.104796  0.421236 -0.266907 -0.641243 -0.945591  0.184468
# 2   0.927897  0.339054 -0.472869  0.441785 -0.643713  0.376308  0.829163
# 3   0.733989 -0.402193  0.674315  0.490025  0.282367  0.812361  0.029223
# 4   0.317633 -0.043078 -0.530109  0.787481 -0.585946  0.678637 -0.646072
# 5   0.624877 -0.218197  0.396334  0.180337  0.457697 -0.653839 -0.639435
# 6   0.782675  0.039371  0.515059  0.773387 -0.372747 -0.787249 -0.370334
# 7   0.173266  0.704518  0.698445  0.346613  0.732416 -0.080294 -0.712289
# 8   0.635374 -0.298850  0.686124  0.317236 -0.108118  0.436635 -0.581868
# 9  -0.087011 -0.761807  0.723683 -0.534594  0.079487  0.331754  0.047056
# 10  0.953151  0.649269  0.683317  0.257834 -0.282350  0.011176  0.723685
# 11 -0.886373  0.202962  0.385750  0.867629  0.988120 -0.562243 -0.129545
# ...

# %%
pd.DataFrame(-1+2*np.random.rand(40,20))*100
# Out:
#            0          1          2          3          4          5   \
# 0   11.335261 -26.426169  38.461663 -32.902993 -93.593117 -81.189983
# 1  -14.323602 -32.112304  86.681132  93.249875  -8.493313  25.881453
# 2   45.540717 -29.994238  22.947374  91.830963  24.613095  90.364827
# 3   76.368657 -58.863541 -64.280964  24.345933 -50.793459 -42.781980
# 4   95.748182  76.372942  -4.263120 -47.031674 -80.367543  97.128489
# 5   32.461783  59.410233 -51.109732 -82.397009  47.295521  57.299766
# 6  -36.375965 -76.141128 -55.297813   4.426404 -19.735291  99.323363
# 7   93.915054  64.156200 -23.935406  -2.593333  69.840547 -93.346181
# 8  -27.562197  16.046810 -28.518257  -3.057050  18.267815  86.870966
# 9   28.089624  69.946547  56.003578  82.156119  31.596728  61.537591
# 10 -45.126896  32.016956  56.000414 -82.414966  97.877660  25.252350
# 11 -10.864139  80.121095  99.513682   4.858549   7.130440 -39.809216
# 12  13.555441  70.732962  29.787878  58.615857 -75.811334  63.155089
# ...

# %%
np.zeros(1,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c639f5ca3ebf> in <module>()
# ----> 1 np.zeros(1,5)
#
# TypeError: data type not understood

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
fit = np.zeros(5)

# %%
x = pd.DataFrame(-1+2*np.random.rand(5,20))

# %%
for i in np.arange(5):
    fit[i] = x[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e2391c4489f7> in <module>()
#       1 for i in np.arange(5):
# ----> 2     fit[i] = x[i]
#
# ValueError: setting an array element with a sequence.

# %%
x[i]
# Out:
# 0   -0.298998
# 1   -0.602140
# 2   -0.673731
# 3   -0.163529
# 4    0.389736
# Name: 0, dtype: float64

# %%
x.iloc[1]
# Out:
# 0    -0.602140
# 1    -0.735884
# 2    -0.447889
# 3     0.810949
# 4    -0.566725
# 5    -0.228435
# 6     0.527886
# 7    -0.136416
# 8     0.166719
# 9    -0.476555
# 10   -0.707253
# 11    0.780322
# 12    0.923868
# 13   -0.157628
# 14    0.848759
# 15    0.077729
# 16    0.697097
# 17   -0.163353
# 18    0.141370
# 19   -0.617087
# Name: 1, dtype: float64

# %%
fit = np.zeros(20)

# %%
fit = x.iloc[0]

# %%
fit
# Out:
# 0    -0.298998
# 1    -0.708800
# 2    -0.890007
# 3    -0.566310
# 4     0.756634
# 5    -0.073520
# 6    -0.732482
# 7     0.648227
# 8    -0.015339
# 9    -0.074218
# 10    0.240544
# 11   -0.557198
# 12    0.484831
# 13   -0.012429
# 14    0.804889
# 15    0.943136
# 16    0.360764
# 17    0.064816
# 18   -0.100622
# 19    0.395671
# Name: 0, dtype: float64

# %%
fit.type?
# Out:
# Object `fit.type` not found.

# %%
fit.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-76227fc8201c> in <module>()
# ----> 1 fit.type
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
fit.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-a50aee89c555> in <module>()
# ----> 1 fit.type()
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
fit.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8635d8d0abbf> in <module>()
# ----> 1 fit.shape()
#
# TypeError: 'tuple' object is not callable

# %%
fit.shape
# Out:
# (20,)

# %%
fit.dtype
# Out:
# dtype('float64')

# %%
fit[5]
# Out:
# -0.07351976259316673

# %%
fit
# Out:
# 0    -0.298998
# 1    -0.708800
# 2    -0.890007
# 3    -0.566310
# 4     0.756634
# 5    -0.073520
# 6    -0.732482
# 7     0.648227
# 8    -0.015339
# 9    -0.074218
# 10    0.240544
# 11   -0.557198
# 12    0.484831
# 13   -0.012429
# 14    0.804889
# 15    0.943136
# 16    0.360764
# 17    0.064816
# 18   -0.100622
# 19    0.395671
# Name: 0, dtype: float64

# %%
fit.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-72599134cb62> in <module>()
# ----> 1 fit.len
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'len'

# %%
fit.lenth
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-bad77e0260cb> in <module>()
# ----> 1 fit.lenth
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lenth'

# %%
fit.lenth()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-594b55a11eca> in <module>()
# ----> 1 fit.lenth()
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lenth'

# %%
fit.size
# Out:
# 20

# %%
np.abs?

# %%
np.abs(-1)
# Out:
# 1

# %%
fit
# Out:
# 0    -0.298998
# 1    -0.708800
# 2    -0.890007
# 3    -0.566310
# 4     0.756634
# 5    -0.073520
# 6    -0.732482
# 7     0.648227
# 8    -0.015339
# 9    -0.074218
# 10    0.240544
# 11   -0.557198
# 12    0.484831
# 13   -0.012429
# 14    0.804889
# 15    0.943136
# 16    0.360764
# 17    0.064816
# 18   -0.100622
# 19    0.395671
# Name: 0, dtype: float64

# %%
fit.max()
# Out:
# 0.9431355754109967

# %%
fit.abs().max()
# Out:
# 0.9431355754109967

# %%
np.pow(3,4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-c328f5bba146> in <module>()
# ----> 1 np.pow(3,4)
#
# AttributeError: module 'numpy' has no attribute 'pow'

# %%
np.math?

# %%
np.math.pow(3,4)
# Out:
# 81.0

# %%
np.math.sin(5)
# Out:
# -0.9589242746631385

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.exp(5)
# Out:
# 148.4131591025766

# %%
def a():
    print("function a!")
def b():
    print("function b!")

def c(funcs):
    funcs[0]()
    funcs[1]()
func = (a,b)
c(func)
