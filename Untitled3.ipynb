# %%
from pandas_datareader import data

# %%
goog = data.DataReader('GOOG',start='2004',end='2016',data_source='google')
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-2-3e87c26221e6> in <module>()
# ----> 1 goog = data.DataReader('GOOG',start='2004',end='2016',data_source='google')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     313                                  chunksize=25,
#     314                                  retry_count=retry_count, pause=pause,
# --> 315                                  session=session).read()
#     316
# ...

# %%
goog = data.DataReader('GOOG',start='2004',end='2017',data_source='google')
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-3-9a7211bb9ea9> in <module>()
# ----> 1 goog = data.DataReader('GOOG',start='2004',end='2017',data_source='google')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     313                                  chunksize=25,
#     314                                  retry_count=retry_count, pause=pause,
# --> 315                                  session=session).read()
#     316
# ...

# %%
goog = data.DataReader('GOOG',start='2004',end='2017',data_source='yahoo')
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-4-ec01e6f7d7e0> in <module>()
# ----> 1 goog = data.DataReader('GOOG',start='2004',end='2017',data_source='yahoo')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     289     """
#     290     if data_source == "yahoo":
# --> 291         raise ImmediateDeprecationError(DEP_ERROR_MSG.format('Yahoo Daily'))
#     292         return YahooDailyReader(symbols=name, start=start, end=end,
#     293                                 adjust_price=False, chunksize=25,
#
# ImmediateDeprecationError:
# Yahoo Daily has been immediately deprecated due to large breaks in the API without the
# introduction of a stable replacement. Pull Requests to re-enable these data
# connectors are welcome.
#
# ...

# %%
goog = data.DataReader('GOOG',data_source='yahoo')
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-5-b7be21abebea> in <module>()
# ----> 1 goog = data.DataReader('GOOG',data_source='yahoo')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     289     """
#     290     if data_source == "yahoo":
# --> 291         raise ImmediateDeprecationError(DEP_ERROR_MSG.format('Yahoo Daily'))
#     292         return YahooDailyReader(symbols=name, start=start, end=end,
#     293                                 adjust_price=False, chunksize=25,
#
# ImmediateDeprecationError:
# Yahoo Daily has been immediately deprecated due to large breaks in the API without the
# introduction of a stable replacement. Pull Requests to re-enable these data
# connectors are welcome.
#
# ...

# %%
goog=data.DataReader('GOOG',data_source='google',start='3/14/2017',end='4/14/2017')
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-6-9232fe946cec> in <module>()
# ----> 1 goog=data.DataReader('GOOG',data_source='google',start='3/14/2017',end='4/14/2017')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     313                                  chunksize=25,
#     314                                  retry_count=retry_count, pause=pause,
# --> 315                                  session=session).read()
#     316
# ...

# %%
goog=data.DataReader('GOOG',data_source='yahoo',start='3/14/2017',end='4/14/2017')
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-8-c69c8e41ea25> in <module>()
# ----> 1 goog=data.DataReader('GOOG',data_source='yahoo',start='3/14/2017',end='4/14/2017')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     289     """
#     290     if data_source == "yahoo":
# --> 291         raise ImmediateDeprecationError(DEP_ERROR_MSG.format('Yahoo Daily'))
#     292         return YahooDailyReader(symbols=name, start=start, end=end,
#     293                                 adjust_price=False, chunksize=25,
#
# ImmediateDeprecationError:
# Yahoo Daily has been immediately deprecated due to large breaks in the API without the
# introduction of a stable replacement. Pull Requests to re-enable these data
# connectors are welcome.
#
# ...

# %%
baba = data.DataReader('BABA',data_source='yahoo',start='2018/01/01')
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-9-5957974524eb> in <module>()
# ----> 1 baba = data.DataReader('BABA',data_source='yahoo',start='2018/01/01')
#
# /usr/local/lib/python3.5/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     289     """
#     290     if data_source == "yahoo":
# --> 291         raise ImmediateDeprecationError(DEP_ERROR_MSG.format('Yahoo Daily'))
#     292         return YahooDailyReader(symbols=name, start=start, end=end,
#     293                                 adjust_price=False, chunksize=25,
#
# ImmediateDeprecationError:
# Yahoo Daily has been immediately deprecated due to large breaks in the API without the
# introduction of a stable replacement. Pull Requests to re-enable these data
# connectors are welcome.
#
# ...

# %%
baba = data.DataReader('BABA',data_source='morningstar',start='2018/01/01')

# %%
baba.head()
# Out:
#                     Close      High      Low     Open    Volume
# Symbol Date
# BABA   2018-01-01  172.43  172.4300  172.430  172.430         0
#        2018-01-02  183.65  184.1000  175.700  176.399  29916943
#        2018-01-03  184.00  185.6350  181.400  185.190  20121856
#        2018-01-04  185.71  187.7472  184.430  185.900  19473795
#        2018-01-05  190.70  190.7500  186.301  187.170  18168345

# %%
goog = data.DataReader('GOOG',data_source='morningstar',start='2018/01/01')

# %%
goog.head()
# Out:
#                      Close       High        Low     Open   Volume
# Symbol Date
# GOOG   2018-01-01  1046.40  1046.4000  1046.4000  1046.40        0
#        2018-01-02  1065.00  1066.9400  1045.2300  1048.34  1237564
#        2018-01-03  1082.48  1086.2900  1063.2100  1064.31  1430170
#        2018-01-04  1086.40  1093.5699  1084.0017  1088.00  1004605
#        2018-01-05  1102.23  1104.2500  1092.0000  1094.00  1279123

# %%
goog = goog['Close']

# %%
goog.head()
# Out:
# Symbol  Date
# GOOG    2018-01-01    1046.40
#         2018-01-02    1065.00
#         2018-01-03    1082.48
#         2018-01-04    1086.40
#         2018-01-05    1102.23
# Name: Close, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
seaborn.set()

# %%
goog.plot()

# %%
goog = data.DataReader('GOOG',data_source='morningstar',start='2014',end='2018')

# %%
goog = goog['Close']

# %%
goog.plot()

# %%
goog.plot(alpha=0.5,style='-')

# %%
goog.plot(alpha=0.5,style='-')
goog.resample('BA').mean().plot(style=':')
goog.asfreq('BA').plot(style='--');
plt.legend(['input','resample','asfreq'],loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-80776a1bb161> in <module>()
#       1 goog.plot(alpha=0.5,style='-')
# ----> 2 goog.resample('BA').mean().plot(style=':')
#       3 goog.asfreq('BA').plot(style='--');
#       4 plt.legend(['input','resample','asfreq'],loc='upper left')
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    5520                      axis=axis, kind=kind, loffset=loffset,
#    5521                      convention=convention,
# -> 5522                      base=base, key=on, level=level)
#    5523         return _maybe_process_deprecations(r,
#    5524                                            how=how,
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
# ...

# %%
goog.plot(alpha=0.5,style='-')
goog.resample('BA').mean().plot(style=':')
goog.asfreq('BA').plot(style='--')
plt.legend(['input','resample','asfreq'],loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-3842cb9319e4> in <module>()
#       1 goog.plot(alpha=0.5,style='-')
# ----> 2 goog.resample('BA').mean().plot(style=':')
#       3 goog.asfreq('BA').plot(style='--')
#       4 plt.legend(['input','resample','asfreq'],loc='upper left')
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    5520                      axis=axis, kind=kind, loffset=loffset,
#    5521                      convention=convention,
# -> 5522                      base=base, key=on, level=level)
#    5523         return _maybe_process_deprecations(r,
#    5524                                            how=how,
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
# ...

# %%
goog.plot(alpha=0.5,style='--')

# %%
goog.plot(alpha=0.5,style=':')

# %%
goog.resample('BA').mean().plot(style=':')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-874b6dcc41f2> in <module>()
# ----> 1 goog.resample('BA').mean().plot(style=':')
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    5520                      axis=axis, kind=kind, loffset=loffset,
#    5521                      convention=convention,
# -> 5522                      base=base, key=on, level=level)
#    5523         return _maybe_process_deprecations(r,
#    5524                                            how=how,
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#     997     """ create a TimeGrouper and return our resampler """
#     998     tg = TimeGrouper(**kwds)
# ...

# %%
goog.head()
# Out:
# Symbol  Date
# GOOG    2014-03-27    556.9312
#         2014-03-28    558.4570
#         2014-03-31    555.4453
#         2014-04-01    565.6074
#         2014-04-02    565.4478
# Name: Close, dtype: float64

# %%
goog.asfreq('BA').plot(style='--')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-71c716192fb0> in <module>()
# ----> 1 goog.asfreq('BA').plot(style='--')
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in asfreq(self, freq, method, how, normalize, fill_value)
#    5259         from pandas.core.resample import asfreq
#    5260         return asfreq(self, freq, method=method, how=how, normalize=normalize,
# -> 5261                       fill_value=fill_value)
#    5262
#    5263     def at_time(self, time, asof=False):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/resample.py in asfreq(obj, freq, method, how, normalize, fill_value)
#    1427
#    1428     else:
# -> 1429         dti = date_range(obj.index[0], obj.index[-1], freq=freq)
#    1430         dti.name = obj.index.name
#    1431         new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#
# ...

# %%
data = pd.read_csv('/home/ygq/文档/csv/FremontBridge.csv',index_col='Date',parse_dates=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cdef02c6fd1c> in <module>()
# ----> 1 data = pd.read_csv('/home/ygq/文档/csv/FremontBridge.csv',index_col='Date',parse_dates=True)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
data = pd.read_csv('/home/ygq/文档/csv/FremontBridge.csv',index_col='Date',parse_dates=True)

# %%
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
data.columns = ['West','East']
data['Total'] = data.eval('West + East')

# %%
data.head()
# Out:
#                      West  East  Total
# Date
# 2012-10-03 00:00:00   4.0   9.0   13.0
# 2012-10-03 01:00:00   4.0   6.0   10.0
# 2012-10-03 02:00:00   1.0   1.0    2.0
# 2012-10-03 03:00:00   2.0   3.0    5.0
# 2012-10-03 04:00:00   6.0   1.0    7.0

# %%
# %matplotlib inline
import seaborn; seaborn.set()

# %%
data.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
weekly = data.resample('W').sum()
weekly.plot(style=[':','--','-'])
plt.ylabel('Weekly bicycle count');

# %%
daliy = data.resample('D').sum()
daliy.rolling(30,center=True).mean().plot(style=[':','--','-'])
plt.ylabel('mean of 30 days count');

# %%
daliy.rolling(50,center=True,win_type='gaussian').sum(std=10).plot(style=[':','--','-']);

# %%
daliy.rolling(50,center=True,win_type='gaussian').sum().plot(style=[':','--','-']);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-cb26c7573d1d> in <module>()
# ----> 1 daliy.rolling(50,center=True,win_type='gaussian').sum().plot(style=[':','--','-']);
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/window.py in sum(self, *args, **kwargs)
#     677     def sum(self, *args, **kwargs):
#     678         nv.validate_window_func('sum', args, kwargs)
# --> 679         return self._apply_window(mean=False, **kwargs)
#     680
#     681     @Substitution(name='window')
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/window.py in _apply_window(self, mean, how, **kwargs)
#     585
#     586         """
# --> 587         window = self._prep_window(**kwargs)
#     588         center = self.center
#     589
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/window.py in _prep_window(self, **kwargs)
# ...

# %%
by_time = data.groupby(data.index.time).mean()

# %%
by_time.head()
# Out:
#               West      East      Total
# 00:00:00  5.385069  6.701375  12.086444
# 01:00:00  2.962672  3.377210   6.339882
# 02:00:00  2.152067  2.117618   4.269685
# 03:00:00  1.613458  1.377210   2.990668
# 04:00:00  3.538802  2.780452   6.319253

# %%
by_time
# Out:
#                 West        East       Total
# 00:00:00    5.385069    6.701375   12.086444
# 01:00:00    2.962672    3.377210    6.339882
# 02:00:00    2.152067    2.117618    4.269685
# 03:00:00    1.613458    1.377210    2.990668
# 04:00:00    3.538802    2.780452    6.319253
# 05:00:00   16.762770    9.113949   25.876719
# 06:00:00   58.437623   32.276523   90.714145
# 07:00:00  152.931729   72.335462  225.267191
# 08:00:00  204.785855  110.582515  315.368369
# 09:00:00  111.088943   74.806388  185.895332
# 10:00:00   54.832432   42.003931   96.836364
# 11:00:00   46.411794   37.598526   84.010319
# 12:00:00   48.130713   41.223096   89.353808
# 13:00:00   50.429273   45.137525   95.566798
# 14:00:00   52.766699   51.178782  103.945481
# 15:00:00   62.207269   69.160118  131.367387
# 16:00:00   86.109528  129.313360  215.422888
# 17:00:00  121.023576  253.578094  374.601670
# 18:00:00   96.100688  166.057466  262.158153
# 19:00:00   52.037819   76.304519  128.342338
# ...

# %%
hourly_ticks = 4*60*60*np.arange(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-110688e870b9> in <module>()
# ----> 1 hourly_ticks = 4*60*60*np.arange(6)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
hourly_ticks = 4*60*60*np.arange(6)

# %%
hourly_ticks
# Out:
# array([    0, 14400, 28800, 43200, 57600, 72000])

# %%
by_time.plot(xticks=hourly_ticks,style=[':','--','-']);

# %%
by_weekday = data.groupby(data.index.dasyofweek).mean()
by_weekday
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-0a11ab65f35b> in <module>()
# ----> 1 by_weekday = data.groupby(data.index.dasyofweek).mean()
#       2 by_weekday
#
# AttributeError: 'DatetimeIndex' object has no attribute 'dasyofweek'

# %%
by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday
# Out:
#            West       East       Total
# Date
# 0     62.599084  66.010309  128.609393
# 1     67.363610  70.111670  137.475280
# 2     66.754009  69.782503  136.536512
# 3     63.494416  65.357532  128.851947
# 4     57.484818  59.153108  116.637926
# 5     32.186856  28.747566   60.934422
# 6     31.234957  27.272493   58.507450

# %%
by_weekday.index = ['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']

# %%
by_weekday.plot(style=[':','--','-']);

# %%
weekend = np.where(data.index.weekday<5,'Weekday','Weekend')
by_time = data.groupby([weekend,data.index.time]).mean()

# %%
by_time
# Out:
#                         West        East       Total
# Weekday 00:00:00    4.668501    5.621733   10.290234
#         01:00:00    2.413343    2.638239    5.051582
#         02:00:00    1.775103    1.638239    3.413343
#         03:00:00    1.472490    1.248968    2.721458
#         04:00:00    4.237964    3.061898    7.299862
#         05:00:00   21.760660   11.479367   33.240028
#         06:00:00   78.438790   41.792985  120.231774
#         07:00:00  207.257221   95.657497  302.914718
#         08:00:00  273.978680  144.349381  418.328061
#         09:00:00  137.952512   90.207846  228.160358
#         10:00:00   55.192705   42.055747   97.248451
#         11:00:00   40.052994   32.397109   72.450103
#         12:00:00   40.103923   35.026153   75.130076
#         13:00:00   42.297111   38.771664   81.068776
#         14:00:00   45.140990   46.692572   91.833563
#         15:00:00   58.927098   72.116919  131.044017
#         16:00:00   94.859010  158.324622  253.183631
# ...

# %%
weekend.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-99035ce8442c> in <module>()
# ----> 1 weekend.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
fig,ax = plt.subplots(1,2,figsize=(4,5))
by_time.ix['Weekday'].plot(ax=ax[0],title='Weekdays',xticks=hourly_ticks,style=[':','--','-'])
by_time.ix['Weekend'].plot(ax=ax[1],title='Weekdends',xticks=hourly_ticks,style=[':','--','-']);
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
goog.head()
# Out:
# Symbol  Date
# GOOG    2014-03-27    556.9312
#         2014-03-28    558.4570
#         2014-03-31    555.4453
#         2014-04-01    565.6074
#         2014-04-02    565.4478
# Name: Close, dtype: float64

# %%
goog.plot()

# %%
rng = np.random.RandomState(42)
x = rng.rand(1E6)
y = rng.rand(1E6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-589eb319d2ea> in <module>()
#       1 rng = np.random.RandomState(42)
# ----> 2 x = rng.rand(1E6)
#       3 y = rng.rand(1E6)
#
# mtrand.pyx in mtrand.RandomState.rand()
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# mtrand.pyx in mtrand.cont0_array()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
rng.rand(1E6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-cd72e74d5a09> in <module>()
# ----> 1 rng.rand(1E6)
#
# mtrand.pyx in mtrand.RandomState.rand()
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# mtrand.pyx in mtrand.cont0_array()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
rng.rand(6)
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864,
#        0.15599452])

# %%
rng.rand(1e6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-0317eea989d3> in <module>()
# ----> 1 rng.rand(1e6)
#
# mtrand.pyx in mtrand.RandomState.rand()
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# mtrand.pyx in mtrand.cont0_array()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
1E6
# Out:
# 1000000.0

# %%
rng.rand(1E6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-cd72e74d5a09> in <module>()
# ----> 1 rng.rand(1E6)
#
# mtrand.pyx in mtrand.RandomState.rand()
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# mtrand.pyx in mtrand.cont0_array()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
nrows,ncols = 100000, 100
rng = np.random.RandomState(42)
df1,df2,df3,df4 = (pd.DataFrame(rng.rand(nrows,ncols)) for i in range(4))

# %%
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.374540  0.950714  0.731994  0.598658  0.156019  0.155995  0.058084
# 1  0.031429  0.636410  0.314356  0.508571  0.907566  0.249292  0.410383
# 2  0.642032  0.084140  0.161629  0.898554  0.606429  0.009197  0.101472
# 3  0.051682  0.531355  0.540635  0.637430  0.726091  0.975852  0.516300
# 4  0.103124  0.902553  0.505252  0.826457  0.320050  0.895523  0.389202
#
#          7         8         9     ...           90        91        92  \
# 0  0.866176  0.601115  0.708073    ...     0.119594  0.713245  0.760785
# 1  0.755551  0.228798  0.076980    ...     0.093103  0.897216  0.900418
# 2  0.663502  0.005062  0.160808    ...     0.030500  0.037348  0.822601
# 3  0.322956  0.795186  0.270832    ...     0.990505  0.412618  0.372018
# 4  0.010838  0.905382  0.091287    ...     0.455657  0.620133  0.277381
#
#          93        94        95        96        97        98        99
# ...

# %%
# %timeit df1+df2+df3+df4
# Out:
# 111 ms ± 302 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit pd.eval('df1+df2+df3+df4')
# Out:
# 112 ms ± 579 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
np.allclose(df1+df2+df3+df4,pd.eval('df1+df2+df3+df4'))
# Out:
# True
